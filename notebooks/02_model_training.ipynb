# %%
# Cell 1: Setup
import sys
sys.path.append('../src')

from data_parser import DataParser  # NOT "from data_parser import src"
from feature_engineering import FeatureEngineer
from model import JobFitnessModel, train_and_compare_models

from sklearn.model_selection import train_test_split

# Cell 2: Load Data
parser = DataParser('../data/raw/AI_RESUME_SCREENING.csv')
df = parser.load_data()
df = parser.clean_data()
df = parser.encode_target()

# Cell 3: Feature Engineering
X, y = parser.prepare_for_modeling()
engineer = FeatureEngineer()
X_engineered = engineer.create_all_features(X)
X_final = engineer.get_model_features(X_engineered)
X_scaled = engineer.scale_features(X_final)

# Cell 4: Split Data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)
print(f"Train: {X_train.shape}, Test: {X_test.shape}")

# Cell 5: Train Models
models = train_and_compare_models(X_train, X_test, y_train, y_test)
# Out:
# Dataset loaded: 1000 rows, 11 columns
# Data cleaned: (1000, 11) -> (1000, 11)
# Removed 0 rows
#
# Target Distribution:
# Target
# 1    812
# 0    188
# Name: count, dtype: int64
# Hire Rate: 81.20%
# Starting feature engineering...
# ✓ Extracted skill features
# ✓ Extracted certification features
# ✓ Encoded education levels
# ✓ Encoded job roles
# ✓ Created interaction features
#
# Final feature count: 29
#
# Final model features (24):
# ['Experience (Years)', 'Projects Count', 'AI Score (0-100)', 'skill_count', 'has_python', 'has_ml', 'has_sql', 'has_cloud', 'has_data_viz', 'has_nlp', 'has_cv', 'has_certification', 'cert_count', 'has_google_cert', 'has_aws_cert', 'has_dl_cert', 'education_level', 'role_AI Researcher', 'role_Cybersecurity Analyst', 'role_Data Scientist', 'role_Software Engineer', 'exp_projects_interaction', 'exp_education_interaction', 'skills_projects_interaction']
# Train: (800, 24), Test: (200, 24)
#
# ============================================================
# TRAINING XGBOOST MODEL
# ============================================================
# Training xgboost model...
# Training complete!
#
# ==================================================
# MODEL EVALUATION RESULTS
# ==================================================
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-Score:  1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Reject       1.00      1.00      1.00        38
#         Hire       1.00      1.00      1.00       162
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# Confusion Matrix:
# [[ 38   0]
#  [  0 162]]
#
# ============================================================
# TRAINING RANDOM FOREST MODEL
# ============================================================
# Training random_forest model...
# Training complete!
#
# ==================================================
# MODEL EVALUATION RESULTS
# ==================================================
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1-Score:  1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Reject       1.00      1.00      1.00        38
#         Hire       1.00      1.00      1.00       162
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
#
# Confusion Matrix:
# [[ 38   0]
#  [  0 162]]
#
# ============================================================
# MODEL COMPARISON
# ============================================================
#            XGBoost  Random Forest
# accuracy       1.0            1.0
# precision      1.0            1.0
# recall         1.0            1.0
# f1_score       1.0            1.0
#
# Best Model (by F1-Score): Random Forest
# /Users/prakharbhardwaj/Desktop/Job_fitness_scoring_system/notebooks/../src/data_parser.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df['Certifications'].fillna('None', inplace=True)
# /Users/prakharbhardwaj/Desktop/Job_fitness_scoring_system/notebooks/../src/feature_engineering.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['education_level'].fillna(1, inplace=True)
